# %% [markdown]
# # Mount My Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Install Relevant Libraries

# %% [markdown]
# # Import Relevant libraries

# %%
import pandas as pd

# %% [markdown]
# # Load the data

# %%
bank = pd.read_csv('/content/drive/MyDrive/UG MSC/ML with Big Data Analytics/Project 1/bank-full.csv', sep=';')
bank.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no

# %%
len(bank)
# Out:
# 45211

# %%
bank['y'].value_counts()
# Out:
# y
# no     39922
# yes     5289
# Name: count, dtype: int64

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ### Bank Information

# %%
# Get relevant information about the bank data
bank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  object
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  object
#  4   default    45211 non-null  object
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   contact    45211 non-null  object
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  object
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  object
#  16  y          45211 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 5.9+ MB

# %% [markdown]
# ### Check for Missing Values

# %%
# Check for missing values - Shows no missing values
bank.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %% [markdown]
# ### Data Description - Numerical Values

# %%
# Description of Numerical values
bank.describe().T
# Out:
#             count         mean          std     min    25%    50%     75%  \
# age       45211.0    40.936210    10.618762    18.0   33.0   39.0    48.0
# balance   45211.0  1362.272058  3044.765829 -8019.0   72.0  448.0  1428.0
# day       45211.0    15.806419     8.322476     1.0    8.0   16.0    21.0
# duration  45211.0   258.163080   257.527812     0.0  103.0  180.0   319.0
# campaign  45211.0     2.763841     3.098021     1.0    1.0    2.0     3.0
# pdays     45211.0    40.197828   100.128746    -1.0   -1.0   -1.0    -1.0
# previous  45211.0     0.580323     2.303441     0.0    0.0    0.0     0.0
#
#                max
# age           95.0
# balance   102127.0
# day           31.0
# duration    4918.0
# campaign      63.0
# pdays        871.0
# previous     275.0

# %% [markdown]
# ### Distribution of Numerical Values

# %%
# Plot Histograms for the Numerical values
bank.hist(bins=50, figsize=(20,15))
# Out:
# array([[<Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'balance'}>,
#         <Axes: title={'center': 'day'}>],
#        [<Axes: title={'center': 'duration'}>,
#         <Axes: title={'center': 'campaign'}>,
#         <Axes: title={'center': 'pdays'}>],
#        [<Axes: title={'center': 'previous'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %% [markdown]
# ### Box and Whisker Plot for all Numerical Values

# %%
import matplotlib.pyplot as plt
import seaborn as sns

numerical_cols = bank.select_dtypes(include=['int64', 'float64']).columns

plt.figure(figsize=(15, 10))
for i, col in enumerate(numerical_cols):
    plt.subplot(2, 4, i + 1)
    sns.boxplot(y=bank[col])
    plt.title(f'Box Plot of {col}')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Unique Values in each of the categorical columns

# %%
# Find the unique values in each of the categorical columns
for col in bank.columns:
  if bank[col].dtype == 'object':
    print(f'{col}: {bank[col].unique()}')
    print()
# Out:
# job: ['management' 'technician' 'entrepreneur' 'blue-collar' 'unknown'
#  'retired' 'admin.' 'services' 'self-employed' 'unemployed' 'housemaid'
#  'student']
#
# marital: ['married' 'single' 'divorced']
#
# education: ['tertiary' 'secondary' 'unknown' 'primary']
#
# default: ['no' 'yes']
#
# housing: ['yes' 'no']
#
# loan: ['no' 'yes']
#
# contact: ['unknown' 'cellular' 'telephone']
#
# month: ['may' 'jun' 'jul' 'aug' 'oct' 'nov' 'dec' 'jan' 'feb' 'mar' 'apr' 'sep']
#
# poutcome: ['unknown' 'failure' 'other' 'success']
#
# y: ['no' 'yes']

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ### Normalize Numerical Columns

# %%
# Normalize these columns using Standscaler - [balance, duration, pdays, previous]
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
bank[['balance', 'duration', 'pdays', 'previous']] = scaler.fit_transform(bank[['balance', 'duration', 'pdays', 'previous']])
bank.describe().T
# Out:
#             count          mean        std        min        25%        50%  \
# age       45211.0  4.093621e+01  10.618762  18.000000  33.000000  39.000000
# balance   45211.0  1.257292e-17   1.000011  -3.081149  -0.423772  -0.300280
# day       45211.0  1.580642e+01   8.322476   1.000000   8.000000  16.000000
# duration  45211.0 -7.543751e-18   1.000011  -1.002478  -0.602517  -0.303517
# campaign  45211.0  2.763841e+00   3.098021   1.000000   1.000000   2.000000
# pdays     45211.0  2.011667e-17   1.000011  -0.411453  -0.411453  -0.411453
# previous  45211.0 -1.408167e-16   1.000011  -0.251940  -0.251940  -0.251940
#
#                 75%         max
# age       48.000000   95.000000
# balance    0.021587   33.094776
# day       21.000000   31.000000
# duration   0.236237   18.094700
# campaign   3.000000   63.000000
# pdays     -0.411453    8.297431
# previous  -0.251940  119.135982

# %% [markdown]
# ### Data Distribution After Normalizing Numerical Variables

# %%
import matplotlib.pyplot as plt
import seaborn as sns

numerical_cols = bank.select_dtypes(include=['int64', 'float64']).columns

plt.figure(figsize=(15, 10))
for i, col in enumerate(numerical_cols):
    plt.subplot(2, 4, i + 1)
    sns.boxplot(y=bank[col])
    plt.title(f'Box Plot of {col}')

plt.tight_layout()
plt.show()

# %%
# Plot Histograms for the Numerical values
bank.hist(bins=50, figsize=(20,15))
# Out:
# array([[<Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'balance'}>,
#         <Axes: title={'center': 'day'}>],
#        [<Axes: title={'center': 'duration'}>,
#         <Axes: title={'center': 'campaign'}>,
#         <Axes: title={'center': 'pdays'}>],
#        [<Axes: title={'center': 'previous'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %% [markdown]
# ### Remove outliers from the data - numerical values

# %%
# Remove outliers using the IQR method
numerical_cols = bank.select_dtypes(include=['int64', 'float64']).columns

for col in numerical_cols:
    Q1 = bank[col].quantile(0.25)
    Q3 = bank[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    bank = bank[(bank[col] >= lower_bound) & (bank[col] <= upper_bound)]

print(f"Shape of the DataFrame after removing outliers: {bank.shape}")
# Out:
# Shape of the DataFrame after removing outliers: (28069, 17)

# %%
bank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 28069 entries, 0 to 45209
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        28069 non-null  int64
#  1   job        28069 non-null  object
#  2   marital    28069 non-null  object
#  3   education  28069 non-null  object
#  4   default    28069 non-null  object
#  5   balance    28069 non-null  float64
#  6   housing    28069 non-null  object
#  7   loan       28069 non-null  object
#  8   contact    28069 non-null  object
#  9   day        28069 non-null  int64
#  10  month      28069 non-null  object
#  11  duration   28069 non-null  float64
#  12  campaign   28069 non-null  int64
#  13  pdays      28069 non-null  float64
#  14  previous   28069 non-null  float64
#  15  poutcome   28069 non-null  object
#  16  y          28069 non-null  object
# dtypes: float64(4), int64(3), object(10)
# memory usage: 3.9+ MB

# %% [markdown]
# ### Data Distribution After Removing Outliers

# %%
import matplotlib.pyplot as plt
import seaborn as sns

numerical_cols = bank.select_dtypes(include=['int64', 'float64']).columns

plt.figure(figsize=(15, 10))
for i, col in enumerate(numerical_cols):
    plt.subplot(2, 4, i + 1)
    sns.boxplot(y=bank[col])
    plt.title(f'Box Plot of {col}')

plt.tight_layout()
plt.show()

# %%
# Plot Histograms for the Numerical values
bank.hist(bins=50, figsize=(20,15))
# Out:
# array([[<Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'balance'}>,
#         <Axes: title={'center': 'day'}>],
#        [<Axes: title={'center': 'duration'}>,
#         <Axes: title={'center': 'campaign'}>,
#         <Axes: title={'center': 'pdays'}>],
#        [<Axes: title={'center': 'previous'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %% [markdown]
# ### Encode the Categorical Variables

# %%
from sklearn.preprocessing import OneHotEncoder, LabelEncoder

# One-hot encode specified columns
one_hot_cols = ['job', 'marital', 'education', 'contact', 'poutcome']
bank = pd.get_dummies(bank, columns=one_hot_cols, drop_first=True)

# Label encode specified columns
label_encode_cols = ['default', 'housing', 'loan', 'month', 'y']
for col in label_encode_cols:
    le = LabelEncoder()
    bank[col] = le.fit_transform(bank[col])

print("DataFrame after encoding categorical variables:")
display(bank.head())
# Out:
# DataFrame after encoding categorical variables:
#    age  default   balance  housing  loan  day  month  duration  campaign  \
# 0   58        0  0.256419        1     0    5      8  0.011016         1
# 1   44        0 -0.437895        1     0    5      8 -0.416127         1
# 2   33        0 -0.446762        1     1    5      8 -0.707361         1
# 3   47        0  0.047205        1     0    5      8 -0.645231         1
# 4   33        0 -0.447091        0     0    5      8 -0.233620         1
#
#       pdays  ...  job_technician  job_unemployed  job_unknown  \
# 0 -0.411453  ...           False           False        False
# 1 -0.411453  ...            True           False        False
# 2 -0.411453  ...           False           False        False
# 3 -0.411453  ...           False           False        False
# 4 -0.411453  ...           False           False         True
#
#    marital_married  marital_single  education_secondary  education_tertiary  \
# 0             True           False                False                True
# 1            False            True                 True               False
# 2             True           False                 True               False
# 3             True           False                False               False
# 4            False            True                False               False
#
#    education_unknown  contact_telephone  contact_unknown
# 0              False              False             True
# 1              False              False             True
# 2              False              False             True
# 3               True              False             True
# 4               True              False             True
#
# [5 rows x 30 columns]

# %%
# Information on resulting data
bank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 28069 entries, 0 to 45209
# Data columns (total 30 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  28069 non-null  int64
#  1   default              28069 non-null  int64
#  2   balance              28069 non-null  float64
#  3   housing              28069 non-null  int64
#  4   loan                 28069 non-null  int64
#  5   day                  28069 non-null  int64
#  6   month                28069 non-null  int64
#  7   duration             28069 non-null  float64
#  8   campaign             28069 non-null  int64
#  9   pdays                28069 non-null  float64
#  10  previous             28069 non-null  float64
#  11  y                    28069 non-null  int64
#  12  job_blue-collar      28069 non-null  bool
#  13  job_entrepreneur     28069 non-null  bool
#  14  job_housemaid        28069 non-null  bool
#  15  job_management       28069 non-null  bool
#  16  job_retired          28069 non-null  bool
#  17  job_self-employed    28069 non-null  bool
#  18  job_services         28069 non-null  bool
#  19  job_student          28069 non-null  bool
#  20  job_technician       28069 non-null  bool
#  21  job_unemployed       28069 non-null  bool
#  22  job_unknown          28069 non-null  bool
#  23  marital_married      28069 non-null  bool
#  24  marital_single       28069 non-null  bool
#  25  education_secondary  28069 non-null  bool
#  26  education_tertiary   28069 non-null  bool
#  27  education_unknown    28069 non-null  bool
#  28  contact_telephone    28069 non-null  bool
#  29  contact_unknown      28069 non-null  bool
# dtypes: bool(18), float64(4), int64(8)
# memory usage: 3.3 MB

# %%
# Label Encode all the boolean variables.
for col in bank.columns:
  if bank[col].dtype == 'bool':
    bank[col] = bank[col].astype(int)
bank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 28069 entries, 0 to 45209
# Data columns (total 30 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  28069 non-null  int64
#  1   default              28069 non-null  int64
#  2   balance              28069 non-null  float64
#  3   housing              28069 non-null  int64
#  4   loan                 28069 non-null  int64
#  5   day                  28069 non-null  int64
#  6   month                28069 non-null  int64
#  7   duration             28069 non-null  float64
#  8   campaign             28069 non-null  int64
#  9   pdays                28069 non-null  float64
#  10  previous             28069 non-null  float64
#  11  y                    28069 non-null  int64
#  12  job_blue-collar      28069 non-null  int64
#  13  job_entrepreneur     28069 non-null  int64
#  14  job_housemaid        28069 non-null  int64
#  15  job_management       28069 non-null  int64
#  16  job_retired          28069 non-null  int64
#  17  job_self-employed    28069 non-null  int64
#  18  job_services         28069 non-null  int64
#  19  job_student          28069 non-null  int64
#  20  job_technician       28069 non-null  int64
#  21  job_unemployed       28069 non-null  int64
#  22  job_unknown          28069 non-null  int64
#  23  marital_married      28069 non-null  int64
#  24  marital_single       28069 non-null  int64
#  25  education_secondary  28069 non-null  int64
#  26  education_tertiary   28069 non-null  int64
#  27  education_unknown    28069 non-null  int64
#  28  contact_telephone    28069 non-null  int64
#  29  contact_unknown      28069 non-null  int64
# dtypes: float64(4), int64(26)
# memory usage: 6.6 MB

# %%
# Save the resulting data to drive
bank.to_csv('/content/drive/MyDrive/UG MSC/ML with Big Data Analytics/Project 1/bank_cleaned.csv', index=False)

# %% [markdown]
# ### Handle Data Imbalance

# %%
# Find the number of records per class
bank['y'].value_counts()
# Out:
# y
# 0    26504
# 1     1565
# Name: count, dtype: int64

# %%
# Keep all the records for class '1' and pick 1600 records for class '0'
bank_balanced = bank[bank['y'] == 1].sample(n=1565, random_state=42)
bank_balanced = pd.concat([bank_balanced, bank[bank['y'] == 0].sample(n=1565, random_state=42)])
bank_balanced['y'].value_counts()
# Out:
# y
# 1    1565
# 0    1565
# Name: count, dtype: int64

# %%
# Keep all the records for class '1' and pick 1600 records for class '0'
bank_balanced = bank[bank['y'] == 1].sample(n=1565, random_state=42)
bank_balanced = pd.concat([bank_balanced, bank[bank['y'] == 0].sample(n=1565, random_state=42)])
bank_balanced['y'].value_counts()

# %%
# Save the balanced dataset
bank_balanced.to_csv('/content/drive/MyDrive/UG MSC/ML with Big Data Analytics/Project 1/bank_balanced.csv', index=False)

# %%
pip install imblearn
# Out:
# Collecting imblearn
#   Downloading imblearn-0.0-py2.py3-none-any.whl.metadata (355 bytes)
# Collecting imbalanced-learn (from imblearn)
#   Downloading imbalanced_learn-0.14.0-py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: numpy<3,>=1.25.2 in ./.venv/lib/python3.13/site-packages (from imbalanced-learn->imblearn) (2.3.5)
# Collecting scipy<2,>=1.11.4 (from imbalanced-learn->imblearn)
#   Downloading scipy-1.16.3-cp313-cp313-macosx_14_0_arm64.whl.metadata (62 kB)
# Collecting scikit-learn<2,>=1.4.2 (from imbalanced-learn->imblearn)
#   Downloading scikit_learn-1.7.2-cp313-cp313-macosx_12_0_arm64.whl.metadata (11 kB)
# Collecting joblib<2,>=1.2.0 (from imbalanced-learn->imblearn)
#   Using cached joblib-1.5.2-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl<4,>=2.0.0 (from imbalanced-learn->imblearn)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading imblearn-0.0-py2.py3-none-any.whl (1.9 kB)
# Downloading imbalanced_learn-0.14.0-py3-none-any.whl (239 kB)
# Using cached joblib-1.5.2-py3-none-any.whl (308 kB)
# Downloading scikit_learn-1.7.2-cp313-cp313-macosx_12_0_arm64.whl (8.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 517.1 kB/s eta 0:00:0000:0100:01
# Downloading scipy-1.16.3-cp313-cp313-macosx_14_0_arm64.whl (20.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.9/20.9 MB 374.0 kB/s eta 0:00:0000:0100:02
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn, imbalanced-learn, imblearn
# Successfully installed imbalanced-learn-0.14.0 imblearn-0.0 joblib-1.5.2 scikit-learn-1.7.2 scipy-1.16.3 threadpoolctl-3.6.0
#
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Feature Engineering

# %%
from imblearn.under_sampling import NearMiss

# %%
from collections import Counter

# %% [markdown]
# # Model Building

# %% [markdown]
# # Model Evaluation

# %% [markdown]
# # Hyperparameter Tuning

# %% [markdown]
# # Model Deployment
